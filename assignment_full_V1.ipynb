# %%
import pyomo.environ as pe
import pyomo.opt as po

# %%
solver = po.SolverFactory("gurobi")
model = pe.ConcreteModel()

# %% [markdown]
# ### Sets Lookup Cell

# %%
factories = {
    "Ijmuiden",
    "Segal",
    "South Wales",
}

customers = {
    "Bochum",
    "Boenen",
    "Dortmund",
    "Gelsenkirchen",
    "Hagen",
    "Iserlohn",
    "Neuss",
    "Schwerte",
}

rebar_types = {"A", "B", "C"}
long_bar_types = {"Type 1", "Type 2"}

# %% [markdown]
# ### Parameter Lookup cell

# %%
capacity = {
    "Ijmuiden": 12,
    "Segal": 10,
    "South Wales": 28,
}

factory_fixed_cost = {
    "Ijmuiden": 400,
    "Segal": 500,
    "South Wales": 250,
}

factory_variable_cost = {
    "Ijmuiden": 5,
    "Segal": 3,
    "South Wales": 2,
}

transport_fixed_cost = {
    "Ijmuiden": 130,
    "Segal": 150,
    "South Wales": 100,
}

uncut_bar_weight = {  # in tonnes
    "Type 1": 0.1803,
    "Type 2": 0.2404,
}

rebar_weight = {  # in tonnes
    "A": 0.0481,
    "B": 0.0721,
    "C": 0.0841,
}

patterns = { # for reference
    ("Type 1", 1): (3, 0, 0),
    ("Type 1", 2): (2, 1, 0),
    ("Type 1", 3): (0, 2, 0),
    ("Type 1", 4): (0, 1, 1),
    ("Type 1", 5): (0, 0, 2),
    ("Type 1", 6): (2, 0, 1),
    ("Type 2", 1): (5, 0, 0),
    ("Type 2", 2): (3, 1, 0),
    ("Type 2", 3): (3, 0, 1),
    ("Type 2", 4): (2, 2, 0),
    ("Type 2", 5): (1, 1, 1),
    ("Type 2", 6): (1, 0, 2),
    ("Type 2", 7): (1, 2, 0),
    ("Type 2", 8): (0, 1, 2),
    ("Type 2", 9): (0, 2, 1),
}

rebars_from_pattern = {
    ("Type 1", 1, "A"): 3,
    ("Type 1", 1, "B"): 0,
    ("Type 1", 1, "C"): 0,
    ("Type 1", 2, "A"): 2,
    ("Type 1", 2, "B"): 1,
    ("Type 1", 2, "C"): 0,
    ("Type 1", 3, "A"): 0,
    ("Type 1", 3, "B"): 2,
    ("Type 1", 3, "C"): 0,
    ("Type 1", 4, "A"): 0,
    ("Type 1", 4, "B"): 1,
    ("Type 1", 4, "C"): 1,
    ("Type 1", 5, "A"): 0,
    ("Type 1", 5, "B"): 0,
    ("Type 1", 5, "C"): 2,
    ("Type 1", 6, "A"): 2,
    ("Type 1", 6, "B"): 0,
    ("Type 1", 6, "C"): 1,
    ("Type 2", 1, "A"): 5,
    ("Type 2", 1, "B"): 0,
    ("Type 2", 1, "C"): 0,
    ("Type 2", 2, "A"): 3,
    ("Type 2", 2, "B"): 1,
    ("Type 2", 2, "C"): 0,
    ("Type 2", 3, "A"): 3,
    ("Type 2", 3, "B"): 0,
    ("Type 2", 3, "C"): 1,
    ("Type 2", 4, "A"): 2,
    ("Type 2", 4, "B"): 2,
    ("Type 2", 4, "C"): 0,
    ("Type 2", 5, "A"): 1,
    ("Type 2", 5, "B"): 1,
    ("Type 2", 5, "C"): 1,
    ("Type 2", 6, "A"): 1,
    ("Type 2", 6, "B"): 0,
    ("Type 2", 6, "C"): 2,
    ("Type 2", 7, "A"): 1,
    ("Type 2", 7, "B"): 2,
    ("Type 2", 7, "C"): 0,
    ("Type 2", 8, "A"): 0,
    ("Type 2", 8, "B"): 1,
    ("Type 2", 8, "C"): 2,
    ("Type 2", 9, "A"): 0,
    ("Type 2", 9, "B"): 2,
    ("Type 2", 9, "C"): 1,
}

demand = {
    (1, "Bochum", "A"): 2,
    (1, "Boenen", "A"): 4,
    (1, "Dortmund", "A"): 2,
    (1, "Gelsenkirchen", "A"): 5,
    (1, "Hagen", "A"): 19,
    (1, "Iserlohn", "A"): 13,
    (1, "Neuss", "A"): 20,
    (1, "Schwerte", "A"): 4,

    (2, "Bochum", "A"):6,
    (2, "Boenen", "A"):8,
    (2, "Dortmund", "A"):7,
    (2, "Gelsenkirchen", "A"):5,
    (2, "Hagen", "A"):23,
    (2, "Iserlohn", "A"):19,
    (2, "Neuss", "A"):16 ,
    (2, "Schwerte", "A"):5,

    (3, "Bochum", "A"):5,
    (3, "Boenen", "A"):5,
    (3, "Dortmund", "A"):6,
    (3, "Gelsenkirchen", "A"):5,
    (3, "Hagen", "A"):25,
    (3, "Iserlohn", "A"):17,
    (3, "Neuss", "A"):14,
    (3, "Schwerte", "A"):3,

    (4, "Bochum", "A"):3,
    (4, "Boenen", "A"):10,
    (4, "Dortmund", "A"):5,
    (4, "Gelsenkirchen", "A"):5,
    (4, "Hagen", "A"):16,
    (4, "Iserlohn", "A"):14,
    (4, "Neuss", "A"):26,
    (4, "Schwerte", "A"):4,


    (1, "Bochum", "B"): 4,
    (1, "Boenen", "B"): 5,
    (1, "Dortmund", "B"): 4,
    (1, "Gelsenkirchen", "B"): 9,
    (1, "Hagen", "B"): 15,
    (1, "Iserlohn", "B"): 22,
    (1, "Neuss", "B"): 12,
    (1, "Schwerte", "B"): 2,

    (2, "Bochum", "B"):5,
    (2, "Boenen", "B"):8,
    (2, "Dortmund", "B"):5,
    (2, "Gelsenkirchen", "B"):10,
    (2, "Hagen", "B"):33,
    (2, "Iserlohn", "B"):26,
    (2, "Neuss", "B"):23,
    (2, "Schwerte", "B"):8 ,

    (3, "Bochum", "B"):7,
    (3, "Boenen", "B"):12,
    (3, "Dortmund", "B"):8,
    (3, "Gelsenkirchen", "B"):6,
    (3, "Hagen", "B"):31,
    (3, "Iserlohn", "B"):20,
    (3, "Neuss", "B"):30,
    (3, "Schwerte", "B"):2,

    (4, "Bochum", "B"):8,
    (4, "Boenen", "B"):13,
    (4, "Dortmund", "B"):10,
    (4, "Gelsenkirchen", "B"):6,
    (4, "Hagen", "B"):33,
    (4, "Iserlohn", "B"):27,
    (4, "Neuss", "B"):30,
    (4, "Schwerte", "B"):6,

    (1, "Bochum", "C"): 6,
    (1, "Boenen", "C"): 6,
    (1, "Dortmund", "C"): 7,
    (1, "Gelsenkirchen", "C"): 10,
    (1, "Hagen", "C"): 12,
    (1, "Iserlohn", "C"): 14,
    (1, "Neuss", "C"): 22,
    (1, "Schwerte", "C"): 5,

    (2, "Bochum", "C"): 7,
    (2, "Boenen", "C"): 10,
    (2, "Dortmund", "C"): 6,
    (2, "Gelsenkirchen", "C"): 9,
    (2, "Hagen", "C"): 35,
    (2, "Iserlohn", "C"): 25,
    (2, "Neuss", "C"): 32,
    (2, "Schwerte", "C"): 6,

    (3, "Bochum", "C"): 7,
    (3, "Boenen", "C"): 15,
    (3, "Dortmund", "C"): 4,
    (3, "Gelsenkirchen", "C"): 9,
    (3, "Hagen", "C"): 33,
    (3, "Iserlohn", "C"): 23,
    (3, "Neuss", "C"): 31,
    (3, "Schwerte", "C"): 7,

    (4, "Bochum", "C"): 7,
    (4, "Boenen", "C"): 12,
    (4, "Dortmund", "C"): 12,
    (4, "Gelsenkirchen", "C"): 10,
    (4, "Hagen", "C"): 38,
    (4, "Iserlohn", "C"): 24,
    (4, "Neuss", "C"): 31,
    (4, "Schwerte", "C"): 2,
}

transport_distances = {
    ("Ijmuiden", "Bochum"): 250,
    ("Segal", "Bochum"): 203,
    ("South Wales", "Bochum"): 866,
    ("Ijmuiden", "Boenen"): 282,
    ("Segal", "Boenen"): 242,
    ("South Wales", "Boenen"): 914,
    ("Ijmuiden", "Dortmund"): 266,
    ("Segal", "Dortmund"): 222,
    ("South Wales", "Dortmund"): 885,
    ("Ijmuiden", "Gelsenkirchen"): 234,
    ("Segal", "Gelsenkirchen"): 198,
    ("South Wales", "Gelsenkirchen"): 859,
    ("Ijmuiden", "Hagen"): 289,
    ("Segal", "Hagen"): 206,
    ("South Wales", "Hagen"): 903,
    ("Ijmuiden", "Iserlohn"): 299,
    ("Segal", "Iserlohn"): 226,
    ("South Wales", "Iserlohn"): 913,
    ("Ijmuiden", "Neuss"): 259,
    ("Segal", "Neuss"): 140,
    ("South Wales", "Neuss"): 843,
    ("Ijmuiden", "Schwerte"): 279,
    ("Segal", "Schwerte"): 216,
    ("South Wales", "Schwerte"): 901,
}

# %% [markdown]
# ### Pyomo Model | Sets

# %%
model.Factories = pe.Set(initialize=factories, ordered=False)
model.Bars = pe.Set(initialize=long_bar_types, ordered=False)
model.Rebars = pe.Set(initialize=rebar_types, ordered=False)
model.Customers = pe.Set(initialize=customers, ordered=False)

model.Periods = pe.RangeSet(1, 4)
model.PatternsType1 = pe.RangeSet(1, 6)
model.PatternsType2 = pe.RangeSet(1, 9)

# %% [markdown]
# ### Pyomo Model | Variables

# %%
# First, we would like to know which factory is used for producing bars
model.factory_active = pe.Var(
    model.Periods,
    model.Factories,
    domain=pe.Binary,
)

# Next, we track what type of long bar is produced by each factory
model.production_bar = pe.Var(
    model.Periods,
    model.Factories,
    model.Bars,
    domain=pe.NonNegativeIntegers,
)

# Afterwards, we want to know how the factories cut their bars
model.rebars_cut_type1 = pe.Var(
    model.Periods,
    model.Factories,
    model.PatternsType1,
    domain=pe.NonNegativeIntegers,
)

model.rebars_cut_type2 = pe.Var(
    model.Periods,
    model.Factories,
    model.PatternsType2,
    domain=pe.NonNegativeIntegers,
)

# Thereafter, we want to know which customers are served from which factory
model.ships = pe.Var(
    model.Periods,
    model.Factories,
    model.Customers,
    domain=pe.Binary,
)

# Finally, how many rebars is carried for each shipment
model.carries = pe.Var(
    model.Periods,
    model.Factories,
    model.Customers,
    model.Rebars,
    domain=pe.NonNegativeIntegers,
)

# %% [markdown]
# ### Pyomo Model | Objective

# %%
# Cost for having a factory open
cost_factory_open = sum(
    model.factory_active[period, factory] * factory_fixed_cost[factory] for factory in model.Factories for period in model.Periods
)

# variable cost for producing bars
cost_producing_bars = sum(
    model.production_bar[period, factory, bar] * factory_variable_cost[factory] for bar in model.Bars for factory in model.Factories for period in model.Periods
)

# fixed cost for shipping
cost_shipment = sum(
    model.ships[period, factory, customer] * transport_fixed_cost[factory] for customer in model.Customers for factory in model.Factories for period in model.Periods
)

# Variable cost for shipping

cost_per_km_tonnes = sum(sum(model.carries[period, factory, customer, rebar] * rebar_weight[rebar] for rebar in model.Rebars) * transport_distances[factory, customer] * 0.5
                         for customer in model.Customers for factory in model.Factories for period in model.Periods
)

### Total objective
objective = cost_factory_open + cost_producing_bars + cost_shipment + cost_per_km_tonnes
model.obj = pe.Objective(sense=pe.minimize, expr=objective)

# %% [markdown]
# ### Pyomo Model | Constraints

# %%
model.maxProd = pe.ConstraintList()

# You cannot produce more than capacity
for period in model.Periods:
    for factory in model.Factories:
        expr = sum(model.production_bar[period, factory, bar] * uncut_bar_weight[bar] for bar in model.Bars) <= capacity[factory]
        model.maxProd.add(expr=expr)
        # print(expr) # Uncomment to see constarint

# %%
model.factoryOpen = pe.ConstraintList()

# You can only produce bars if the factory is active
for period in model.Periods:
    for factory in model.Factories:
        expr = sum(model.production_bar[period, factory, bar] for bar in model.Bars) <= model.factory_active[period, factory] * 10000
        
        model.factoryOpen.add(expr=expr)
        # print(expr) # Uncomment to see constarint

# %%
model.cuttingBars = pe.ConstraintList()

# the number of patterns that we cut should be equal to the number of bars that we produced
for period in model.Periods:
        for factory in model.Factories:
                
                # Type 1 bar
                expr = (sum(model.rebars_cut_type1[period, factory, pattern] for pattern in model.PatternsType1) ) <= model.production_bar[period, factory, 'Type 1']
                model.cuttingBars.add(expr=expr)
                # print(expr) # Uncomment to see constarint
                
                # Type 2 bar
                expr = (sum(model.rebars_cut_type2[period, factory, pattern] for pattern in model.PatternsType2) ) <= model.production_bar[period, factory, 'Type 2']
                model.cuttingBars.add(expr=expr)
                # print(expr) # Uncomment to see constarint

# %%
model.onlyOneFactory = pe.ConstraintList()

# Each customer can only be served by one factory
for period in model.Periods:
    for customer in model.Customers:
        expr = sum(model.ships[period, factory, customer] for factory in model.Factories) == 1
        model.onlyOneFactory.add(expr=expr)
        # print(expr)  # Uncomment to see constarint

# %%
model.carryCapacity = pe.ConstraintList()

# A shipment cannot carry more than is produced
for period in model.Periods:
    for factory in model.Factories:
        for rebar in model.Rebars:
            
            available_rebars_from_type1 = sum(model.rebars_cut_type1[period, factory, pattern] * rebars_from_pattern['Type 1', pattern, rebar] for pattern in model.PatternsType1)
            available_rebars_from_type2 = sum(model.rebars_cut_type2[period, factory, pattern] * rebars_from_pattern['Type 2', pattern, rebar] for pattern in model.PatternsType2)
            
            expr = sum(model.carries[period, factory, customer, rebar] for customer in model.Customers) <= available_rebars_from_type1 + available_rebars_from_type2
            
            model.carryCapacity.add(expr=expr)
            # print(expr)  # Uncomment to see constarint

# %%
model.meetDemand = pe.ConstraintList()

# Each demand should be met
for period in model.Periods:
    for factory in model.Factories:
        for customer in model.Customers:
            for rebar in model.Rebars:
                expr = model.carries[period, factory, customer, rebar] == model.ships[period, factory, customer] * demand[period, customer, rebar]
            
                model.meetDemand.add(expr=expr)
                # print(expr)  # Uncomment to see constarint

# %% [markdown]
# ### Pyomo Model | Solver

# %%
result = solver.solve(model, tee = True, options = {'TimeLimit':3600})
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-04
# Read LP format model from file /var/folders/xk/nwlnsjsx3c321c24ljrms4mc0000gn/T/tmpamta1_4t.pyomo.lp
# Reading time = 0.00 seconds
# x1: 404 rows, 600 columns, 1548 nonzeros
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 404 rows, 600 columns and 1548 nonzeros
# Model fingerprint: 0xda695225
# Variable types: 0 continuous, 600 integer (108 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+04]
#   Objective range  [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 375 rows and 525 columns
# Presolve time: 0.12s
# Presolved: 29 rows, 75 columns, 234 nonzeros
# Variable types: 0 continuous, 75 integer (27 binary)
#
# Root relaxation: objective 2.196866e+04, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 21968.6587    0   19          - 21968.6587      -     -    0s
# H    0     0                    24675.390270 21968.6587  11.0%     -    0s
# H    0     0                    23548.933720 21968.6587  6.71%     -    0s
# H    0     0                    23536.933720 21968.6587  6.66%     -    0s
# H    0     0                    23519.933720 21968.6587  6.60%     -    0s
# H    0     0                    23508.142520 21968.6587  6.55%     -    0s
#      0     0 22551.8418    0   13 23508.1425 22551.8418  4.07%     -    0s
#      0     0 22552.7680    0   15 23508.1425 22552.7680  4.06%     -    0s
# H    0     0                    23503.142520 22552.7680  4.04%     -    0s
# H    0     0                    22900.955520 22552.7680  1.52%     -    0s
# H    0     0                    22892.955520 22552.7680  1.49%     -    0s
# H    0     0                    22882.955520 22552.7680  1.44%     -    0s
# H    0     0                    22675.270320 22576.2181  0.44%     -    0s
# H    0     0                    22673.270320 22576.2181  0.43%     -    0s
#      0     0 22591.6818    0   26 22673.2703 22591.6818  0.36%     -    0s
#      0     0 22591.6818    0   23 22673.2703 22591.6818  0.36%     -    0s
# H    0     0                    22605.058970 22603.2095  0.01%     -    0s
#      0     0 22603.2095    0   25 22605.0590 22603.2095  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 1
#   MIR: 3
#
# Explored 1 nodes (99 simplex iterations) in 0.13 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 22605.1 22673.3 22675.3 ... 23536.9
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max bound violation (3.7794e-06) exceeds tolerance
# Best objective 2.260505897008e+04, best bound 2.260320950049e+04, gap 0.0082%

# %% [markdown]
# ### Pyomo Model | Results

# %%
print(f"objective value is: {pe.value(model.obj)}")

# Which factories where open?
print('\nOpen factories:')
for period in model.Periods:
    for factory in model.Factories:
        if pe.value(model.factory_active[period, factory]) > 0:
            print(f"{period, factory} : {pe.value(model.factory_active[period, factory])}")
    
# how many bars did we produce?
print('\nHow many bars produced:')
for period in model.Periods:
    for factory in model.Factories:
        for bar in model.Bars:
            if pe.value(model.production_bar[period, factory, bar]) > 0:
                print(f"{period, factory, bar} : {pe.value(model.production_bar[period, factory, bar])}")
 
 # how many patterns did we cut?
print('\npatterns from steel bar type 1:')
for period in model.Periods:
    for factory in model.Factories:
        for pattern in model.PatternsType1:
            if pe.value(model.rebars_cut_type1[period, factory, pattern]) > 0:
                print(f"{period, factory, pattern} : {pe.value(model.rebars_cut_type1[period, factory, pattern])}")       

 # how many patterns did we cut?
print('\npatterns from steel bar type 2:')
for period in model.Periods:
    for factory in model.Factories:
        for pattern in model.PatternsType2:
            if pe.value(model.rebars_cut_type2[period, factory, pattern]) > 0:
                print(f"{period, factory, pattern} : {pe.value(model.rebars_cut_type2[period, factory, pattern])}")     
        
        
 # how many patterns did we cut?
print('\nWhich customer was served by which factory?')
for period in model.Periods:
    for customer in model.Customers:
        for factory in model.Factories:
            if pe.value(model.ships[period, factory, customer]) > 0:
                print(f"{period, customer, factory} : {pe.value(model.ships[period, factory, customer])}")     


 # how many patterns did we cut?
print('\nhow much did each shipment carry?')
for period in model.Periods:
    for factory in model.Factories:
        for customer in model.Customers:
            for rebar in model.Rebars:
                if pe.value(model.carries[period, factory, customer, rebar]) > 0:
                    print(f"{period, factory, customer, rebar} : {pe.value(model.carries[period, factory, customer, rebar])}")
# Out:
# objective value is: 22605.05897008216
#
# Open factories:
# (1, 'Segal') : 1.0
# (1, 'Ijmuiden') : 1.0
# (2, 'Segal') : 1.0
# (2, 'South Wales') : 1.0
# (2, 'Ijmuiden') : 1.0
# (3, 'Segal') : 1.0
# (3, 'South Wales') : 1.0
# (3, 'Ijmuiden') : 1.0
# (4, 'Segal') : 1.0
# (4, 'South Wales') : 1.0
# (4, 'Ijmuiden') : 1.0
#
# How many bars produced:
# (1, 'Segal', 'Type 2') : 40.0
# (1, 'Ijmuiden', 'Type 2') : 25.0
# (2, 'Segal', 'Type 2') : 40.0
# (2, 'Segal', 'Type 1') : 2.0
# (2, 'South Wales', 'Type 2') : 9.0
# (2, 'South Wales', 'Type 1') : 2.0
# (2, 'Ijmuiden', 'Type 2') : 48.0
# (3, 'Segal', 'Type 2') : 40.0
# (3, 'Segal', 'Type 1') : 2.0
# (3, 'South Wales', 'Type 2') : 6.0
# (3, 'Ijmuiden', 'Type 2') : 49.0
# (3, 'Ijmuiden', 'Type 1') : 1.0
# (4, 'Segal', 'Type 2') : 40.0
# (4, 'Segal', 'Type 1') : 2.0
# (4, 'South Wales', 'Type 2') : 14.0
# (4, 'Ijmuiden', 'Type 2') : 49.0
#
# patterns from steel bar type 1:
# (2, 'Segal', 2) : 1.0
# (2, 'Segal', 6) : 1.0
# (2, 'South Wales', 6) : 2.0
# (3, 'Segal', 1) : 2.0
# (3, 'Ijmuiden', 2) : 1.0
# (4, 'Segal', 6) : 2.0
#
# patterns from steel bar type 2:
# (1, 'Segal', 1) : 5.0
# (1, 'Segal', 4) : 9.0
# (1, 'Segal', 8) : 25.0
# (1, 'Segal', 9) : 1.0
# (1, 'Ijmuiden', 1) : 3.0
# (1, 'Ijmuiden', 4) : 6.0
# (1, 'Ijmuiden', 8) : 15.0
# (1, 'Ijmuiden', 9) : 1.0
# (2, 'Segal', 1) : 2.0
# (2, 'Segal', 4) : 10.0
# (2, 'Segal', 8) : 28.0
# (2, 'South Wales', 1) : 1.0
# (2, 'South Wales', 4) : 2.0
# (2, 'South Wales', 8) : 6.0
# (2, 'Ijmuiden', 1) : 2.999997840999991
# (2, 'Ijmuiden', 4) : 15.0
# (2, 'Ijmuiden', 8) : 30.00000134750001
# (3, 'Segal', 4) : 11.0
# (3, 'Segal', 8) : 28.0
# (3, 'Segal', 9) : 1.0
# (3, 'South Wales', 4) : 2.0
# (3, 'South Wales', 6) : 1.0
# (3, 'South Wales', 8) : 3.0
# (3, 'Ijmuiden', 1) : 4.0
# (3, 'Ijmuiden', 3) : 1.0
# (3, 'Ijmuiden', 4) : 12.0
# (3, 'Ijmuiden', 8) : 32.0
# (4, 'Segal', 1) : 3.0
# (4, 'Segal', 4) : 11.0
# (4, 'Segal', 8) : 25.0
# (4, 'Segal', 9) : 1.0
# (4, 'South Wales', 4) : 4.0
# (4, 'South Wales', 8) : 10.0
# (4, 'Ijmuiden', 4) : 17.0
# (4, 'Ijmuiden', 8) : 32.0
#
# Which customer was served by which factory?
# (1, 'Iserlohn', 'Segal') : 1.0
# (1, 'Hagen', 'Ijmuiden') : 1.0
# (1, 'Gelsenkirchen', 'Segal') : 1.0
# (1, 'Schwerte', 'Segal') : 1.0
# (1, 'Boenen', 'Ijmuiden') : 1.0
# (1, 'Neuss', 'Segal') : 1.0
# (1, 'Bochum', 'Ijmuiden') : 1.0
# (1, 'Dortmund', 'Ijmuiden') : 1.0
# (2, 'Iserlohn', 'Ijmuiden') : 1.0
# (2, 'Hagen', 'Ijmuiden') : 1.0
# (2, 'Gelsenkirchen', 'Segal') : 1.0
# (2, 'Schwerte', 'Segal') : 1.0
# (2, 'Boenen', 'Segal') : 1.0
# (2, 'Neuss', 'Segal') : 1.0
# (2, 'Bochum', 'South Wales') : 1.0000005385714317
# (2, 'Dortmund', 'South Wales') : 0.9999989211302969
# (2, 'Dortmund', 'Ijmuiden') : 1.0785714346643024e-06
# (3, 'Iserlohn', 'Ijmuiden') : 1.0
# (3, 'Hagen', 'Ijmuiden') : 1.0
# (3, 'Gelsenkirchen', 'Ijmuiden') : 1.0
# (3, 'Schwerte', 'Segal') : 1.0
# (3, 'Boenen', 'Segal') : 1.0
# (3, 'Neuss', 'Segal') : 1.0
# (3, 'Bochum', 'South Wales') : 1.0
# (3, 'Dortmund', 'Segal') : 1.0
# (4, 'Iserlohn', 'Ijmuiden') : 1.0
# (4, 'Hagen', 'Ijmuiden') : 1.0
# (4, 'Gelsenkirchen', 'Segal') : 1.0
# (4, 'Schwerte', 'Ijmuiden') : 1.0
# (4, 'Boenen', 'Segal') : 1.0
# (4, 'Neuss', 'Segal') : 1.0
# (4, 'Bochum', 'South Wales') : 1.0
# (4, 'Dortmund', 'South Wales') : 1.0
#
# how much did each shipment carry?
# (1, 'Segal', 'Iserlohn', 'C') : 14.0
# (1, 'Segal', 'Iserlohn', 'B') : 22.0
# (1, 'Segal', 'Iserlohn', 'A') : 13.0
# (1, 'Segal', 'Gelsenkirchen', 'C') : 10.0
# (1, 'Segal', 'Gelsenkirchen', 'B') : 9.0
# (1, 'Segal', 'Gelsenkirchen', 'A') : 5.0
# (1, 'Segal', 'Schwerte', 'C') : 5.0
# (1, 'Segal', 'Schwerte', 'B') : 2.0
# (1, 'Segal', 'Schwerte', 'A') : 4.0
# (1, 'Segal', 'Neuss', 'C') : 22.0
# (1, 'Segal', 'Neuss', 'B') : 12.0
# (1, 'Segal', 'Neuss', 'A') : 20.0
# (1, 'Ijmuiden', 'Hagen', 'C') : 12.0
# (1, 'Ijmuiden', 'Hagen', 'B') : 15.0
# (1, 'Ijmuiden', 'Hagen', 'A') : 19.0
# (1, 'Ijmuiden', 'Boenen', 'C') : 6.0
# (1, 'Ijmuiden', 'Boenen', 'B') : 5.0
# (1, 'Ijmuiden', 'Boenen', 'A') : 4.0
# (1, 'Ijmuiden', 'Bochum', 'C') : 6.0
# (1, 'Ijmuiden', 'Bochum', 'B') : 4.0
# (1, 'Ijmuiden', 'Bochum', 'A') : 2.0
# (1, 'Ijmuiden', 'Dortmund', 'C') : 7.0
# (1, 'Ijmuiden', 'Dortmund', 'B') : 4.0
# (1, 'Ijmuiden', 'Dortmund', 'A') : 2.0
# (2, 'Segal', 'Gelsenkirchen', 'C') : 9.0
# (2, 'Segal', 'Gelsenkirchen', 'B') : 10.0
# (2, 'Segal', 'Gelsenkirchen', 'A') : 5.0
# (2, 'Segal', 'Schwerte', 'C') : 6.0
# (2, 'Segal', 'Schwerte', 'B') : 8.0
# (2, 'Segal', 'Schwerte', 'A') : 5.0
# (2, 'Segal', 'Boenen', 'C') : 10.0
# (2, 'Segal', 'Boenen', 'B') : 8.0
# (2, 'Segal', 'Boenen', 'A') : 8.0
# (2, 'Segal', 'Neuss', 'C') : 32.0
# (2, 'Segal', 'Neuss', 'B') : 23.0
# (2, 'Segal', 'Neuss', 'A') : 16.0
# (2, 'South Wales', 'Bochum', 'C') : 7.000003775000022
# (2, 'South Wales', 'Bochum', 'B') : 5.000002695000016
# (2, 'South Wales', 'Bochum', 'A') : 6.000003235000019
# (2, 'South Wales', 'Dortmund', 'C') : 5.999993523037248
# (2, 'South Wales', 'Dortmund', 'B') : 4.999994603542767
# (2, 'South Wales', 'Dortmund', 'A') : 6.9999924449999575
# (2, 'Ijmuiden', 'Iserlohn', 'C') : 25.0
# (2, 'Ijmuiden', 'Iserlohn', 'B') : 26.0
# (2, 'Ijmuiden', 'Iserlohn', 'A') : 19.0
# (2, 'Ijmuiden', 'Hagen', 'C') : 35.0
# (2, 'Ijmuiden', 'Hagen', 'B') : 33.0
# (2, 'Ijmuiden', 'Hagen', 'A') : 23.0
# (2, 'Ijmuiden', 'Dortmund', 'C') : 6.475000036557243e-06
# (2, 'Ijmuiden', 'Dortmund', 'B') : 5.395000030464369e-06
# (2, 'Ijmuiden', 'Dortmund', 'A') : 7.555000042650117e-06
# (3, 'Segal', 'Schwerte', 'C') : 7.0
# (3, 'Segal', 'Schwerte', 'B') : 2.0
# (3, 'Segal', 'Schwerte', 'A') : 3.0
# (3, 'Segal', 'Boenen', 'C') : 15.0
# (3, 'Segal', 'Boenen', 'B') : 12.0
# (3, 'Segal', 'Boenen', 'A') : 5.0
# (3, 'Segal', 'Neuss', 'C') : 31.0
# (3, 'Segal', 'Neuss', 'B') : 30.0
# (3, 'Segal', 'Neuss', 'A') : 14.0
# (3, 'Segal', 'Dortmund', 'C') : 4.0
# (3, 'Segal', 'Dortmund', 'B') : 8.0
# (3, 'Segal', 'Dortmund', 'A') : 6.0
# (3, 'South Wales', 'Bochum', 'C') : 7.0
# (3, 'South Wales', 'Bochum', 'B') : 7.0
# (3, 'South Wales', 'Bochum', 'A') : 5.0
# (3, 'Ijmuiden', 'Iserlohn', 'C') : 23.0
# (3, 'Ijmuiden', 'Iserlohn', 'B') : 20.0
# (3, 'Ijmuiden', 'Iserlohn', 'A') : 17.0
# (3, 'Ijmuiden', 'Hagen', 'C') : 33.0
# (3, 'Ijmuiden', 'Hagen', 'B') : 31.0
# (3, 'Ijmuiden', 'Hagen', 'A') : 25.0
# (3, 'Ijmuiden', 'Gelsenkirchen', 'C') : 9.0
# (3, 'Ijmuiden', 'Gelsenkirchen', 'B') : 6.0
# (3, 'Ijmuiden', 'Gelsenkirchen', 'A') : 5.0
# (4, 'Segal', 'Gelsenkirchen', 'C') : 10.0
# (4, 'Segal', 'Gelsenkirchen', 'B') : 6.0
# (4, 'Segal', 'Gelsenkirchen', 'A') : 5.0
# (4, 'Segal', 'Boenen', 'C') : 12.0
# (4, 'Segal', 'Boenen', 'B') : 13.0
# (4, 'Segal', 'Boenen', 'A') : 10.0
# (4, 'Segal', 'Neuss', 'C') : 31.0
# (4, 'Segal', 'Neuss', 'B') : 30.0
# (4, 'Segal', 'Neuss', 'A') : 26.0
# (4, 'South Wales', 'Bochum', 'C') : 7.0
# (4, 'South Wales', 'Bochum', 'B') : 8.0
# (4, 'South Wales', 'Bochum', 'A') : 3.0
# (4, 'South Wales', 'Dortmund', 'C') : 12.0
# (4, 'South Wales', 'Dortmund', 'B') : 10.0
# (4, 'South Wales', 'Dortmund', 'A') : 5.0
# (4, 'Ijmuiden', 'Iserlohn', 'C') : 24.0
# (4, 'Ijmuiden', 'Iserlohn', 'B') : 27.0
# (4, 'Ijmuiden', 'Iserlohn', 'A') : 14.0
# (4, 'Ijmuiden', 'Hagen', 'C') : 38.0
# (4, 'Ijmuiden', 'Hagen', 'B') : 33.0
# (4, 'Ijmuiden', 'Hagen', 'A') : 16.0
# (4, 'Ijmuiden', 'Schwerte', 'C') : 2.0
# (4, 'Ijmuiden', 'Schwerte', 'B') : 6.0
# (4, 'Ijmuiden', 'Schwerte', 'A') : 4.0

# %% [markdown]
# ### Pyomo Model | Diagnostics

# %%
print(f"\nstatus: {result.solver.status}, condition: {result.solver.termination_condition}")
# Out:
# status: ok, condition: optimal
